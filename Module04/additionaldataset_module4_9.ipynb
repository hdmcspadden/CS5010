# %%
#4.9 Discussion: NumPy and Pandas Group Assignment
#Katelyn Barbre, Caprill Wright
#kb3kk, acw2et
#9/13/20

# %%
cd C:\Users\Caprill\Desktop\Python
# Out:
# C:\Users\Caprill\Desktop\Python

# %%
from numpy import *
import pandas as pd

# For output purposes to show all columns:
pd.set_option('display.max_columns', None)

# For this other data set, it included headers and was formatted differently so we needed to comment out rows below

#One of the parameters is "skiprows'. So we find the rows to skip
# Skipping first 7 rows (which is range(7)=0 to 6) 
# and rows 6942 to 6979 (which is range (6941,6979) due to rows starting at #0)
#beginningRows = list(range(7))
#endingRows = list(range(6941,6979))
#skips = beginningRows + endingRows

# One of the parameters is "usecols". Used to find the columns of interest.
#useTheseCols = list(range(0,13)) # Grabbing columns including the first

# header=0 means that we assign the headers to first row we read (not including the skipped)
# Read the csv file:
df = pd.read_csv('shootings.csv',header=0,encoding = "ISO-8859-1")

print("  *** Using file: shootings.csv ***")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-cabd2fda0643> in <module>
#      19 # header=0 means that we assign the headers to first row we read (not including the skipped)
#      20 # Read the csv file:
# ---> 21 df = pd.read_csv('shootings.csv',header=0,encoding = "ISO-8859-1")
#      22
#      23 print("  *** Using file: shootings.csv ***")
#
# ...

# %%
# Print the first 5 data points (using "head")
print("\n****************")
print('*** The first 5 data points\n')
df.head(6) # we got rid of including this in the print function so that it looked more like a table
# Out:
# ****************
# *** The first 5 data points
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  1/2/2015              shot         gun  53.0
# 1   4    Lewis Lee Lembke  1/2/2015              shot         gun  47.0
# 2   5  John Paul Quintero  1/3/2015  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  1/4/2015              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  1/4/2015              shot    nail gun  39.0
# 5  11   Kenneth Joe Brown  1/4/2015              shot         gun  18.0
#
#   gender      race           city state  signs_of_mental_illness threat_level  \
# 0      M     Asian        Shelton    WA                     True       attack
# 1      M     White          Aloha    OR                    False       attack
# 2      M  Hispanic        Wichita    KS                    False        other
# 3      M     White  San Francisco    CA                     True       attack
# ...

# %%
# Print the last 5 data points (using "tail")
print("\n****************", end='')
print('\n*** The last 5 data points\n')
df.tail(5)
# Out:
# ****************
# *** The last 5 data points
#         id             name       date manner_of_death    armed   age gender  \
# 4890  5916  Rayshard Brooks  6/12/2020            shot    Taser  27.0      M
# 4891  5925   Caine Van Pelt  6/12/2020            shot      gun  23.0      M
# 4892  5918     Hannah Fizer  6/13/2020            shot  unarmed  25.0      F
# 4893  5921   William Slyter  6/13/2020            shot      gun  22.0      M
# 4894  5924   Nicholas Hirsh  6/15/2020            shot      gun  31.0      M
#
#        race         city state  signs_of_mental_illness threat_level  \
# 4890  Black      Atlanta    GA                    False       attack
# 4891  Black  Crown Point    IN                    False       attack
# 4892  White      Sedalia    MO                    False        other
# 4893  White  Kansas City    MO                    False        other
# 4894  White     Lawrence    KS                    False       attack
#
# ...

# %%
# Print the column headers
print('\n****************')
print('*** The column headers\n')
df.columns
# Out:
# ****************
# *** The column headers
# Index(['id', 'name', 'date', 'manner_of_death', 'armed', 'age', 'gender',
#        'race', 'city', 'state', 'signs_of_mental_illness', 'threat_level',
#        'flee', 'body_camera', 'arms_category'],
#       dtype='object')

# %%
#Query age greater than 50
df[df["age"]>50]
# Out:
#         id                   name       date   manner_of_death  \
# 0        3             Tim Elliot   1/2/2015              shot
# 19      38          Jimmy Foreman   1/9/2015              shot
# 29      52       Talbot Schroeder  1/14/2015              shot
# 30      54         Robert Edwards  1/14/2015              shot
# 43      83          Carter Castle  1/18/2015  shot and Tasered
# ...    ...                    ...        ...               ...
# 4848  5892     Willie Lee Quarles  5/21/2020              shot
# 4858  5847         Joshua Blessed  5/27/2020              shot
# 4862  5853  John Benedict Coleman  5/28/2020              shot
# 4873  5842           David McAtee   6/1/2020              shot
# 4889  5915         Michael Thomas  6/11/2020              shot
#
#                 armed   age gender   race          city state  \
# 0                 gun  53.0      M  Asian       Shelton    WA
# 19                gun  71.0      M  White       England    AR
# ...

# %%
#Query for race
df[df["race"]=='Black']
# Out:
#         id                              name       date manner_of_death  \
# 9       17                   Leslie Sapp III   1/6/2015            shot
# 11      21                         Ron Sneed   1/7/2015            shot
# 12      22    Hashim Hanif Ibn Abdul-Rasheed   1/7/2015            shot
# 14      27  Omarr Julian Maximillian Jackson   1/7/2015            shot
# 17      36               Artago Damon Howard   1/8/2015            shot
# ...    ...                               ...        ...             ...
# 4883  5899                     Kamal Flowers   6/6/2020            shot
# 4886  5911                      Lewis Ruffin   6/9/2020            shot
# 4889  5915                    Michael Thomas  6/11/2020            shot
# 4890  5916                   Rayshard Brooks  6/12/2020            shot
# 4891  5925                    Caine Van Pelt  6/12/2020            shot
#
#            armed   age gender   race          city state  \
# ...

# %%
#summary statistics, We wanted to see the total count of data points, i.e. 4895
df.describe()
# Out:
#                 id          age
# count  4895.000000  4895.000000
# mean   2902.148519    36.549750
# std    1683.467910    12.694348
# min       3.000000     6.000000
# 25%    1441.500000    27.000000
# 50%    2847.000000    35.000000
# 75%    4352.500000    45.000000
# max    5925.000000    91.000000

# %%
#percentage of shooting victims that are Black overall; 26% are African American (1298 Black victims/total)
1298/4895
# Out:
# 0.2651685393258427

# %%
#Query Race: Black by cities
df[df["race"]=='Black'].sort_values(by='city')
# Out:
#         id                   name        date   manner_of_death    armed  \
# 2266  2624  Charles Darnell Baker    6/2/2017              shot      gun
# 4711  5652       Lebarron Ballard   3/18/2020  shot and Tasered    knife
# 4119  4861          Darrell Allen   7/10/2019              shot    knife
# 4593  5435        Aaron T. Booker   1/27/2020              shot      gun
# 1640  1891           Philip Hasan   9/18/2016              shot      gun
# ...    ...                    ...         ...               ...      ...
# 767    930        Dequan Williams  10/17/2015  shot and Tasered    knife
# 449    569      Damien A. Harrell   6/24/2015              shot      gun
# 1772  2048     Rasheem Singletary  11/15/2016              shot  unknown
# 4869  5879        Jarvis Sullivan   5/29/2020              shot  vehicle
# 250    296          Justus Howell    4/4/2015              shot      gun
#
#        age gender   race         city state  signs_of_mental_illness  \
# ...

# %%
#Query Race: Black victims in Chicago
ChicagoBlack = df[(df["race"]=='Black') & (df["city"]=='Chicago')]
ChicagoBlack.count() #wanted to quickly count the number of Black victims in Chicago
# Out:
# id                         32
# name                       32
# date                       32
# manner_of_death            32
# armed                      32
# age                        32
# gender                     32
# race                       32
# city                       32
# state                      32
# signs_of_mental_illness    32
# threat_level               32
# flee                       32
# body_camera                32
# arms_category              32
# dtype: int64

# %%
#Query victims in Chicago by race
df[df["city"]=='Chicago'].sort_values(by='race') #This output is interesting because it shows that only 2 of the people shot by police in Chicago were white
# Out:
#         id                 name        date   manner_of_death         armed  \
# 284    380         Jeffrey Kemp   4/17/2015              shot           gun
# 4008  4746       Curtis Stagger   5/28/2019              shot           gun
# 3998  5423        Myles Frazier   5/22/2019              shot           gun
# 3969  4713        Sharell Brown   5/11/2019              shot           gun
# 3783  4470         Michael Elam   2/16/2019              shot           gun
# 3300  3857      Harith Augustus   7/14/2018              shot           gun
# 3277  3970        Terrell Eason    7/3/2018              shot           gun
# 3211  3755      Maurice Granton    6/6/2018              shot           gun
# 3205  3730           Gus Tousis    6/2/2018              shot       unknown
# 2733  3174     Aquoness Cathery  11/29/2017              shot           gun
# 2269  2628        Corsean Lewis    6/2/2017              shot           gun
# ...
